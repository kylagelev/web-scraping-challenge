# %%
import pandas as pd
from splinter import Browser
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager

# %%
#inputting url
url = 'https://mars.nasa.gov/news/?page=0&per_page=40&order=publish_date+desc%2Ccreated_at+desc&search=&category=19%2C165%2C184%2C204&blank_scope=Latest'

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
browser.visit(url)
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 89.0.4389
# [WDM] - Get LATEST driver version for 89.0.4389
# [WDM] - Driver [/Users/kylagelev/.wdm/drivers/chromedriver/mac64/89.0.4389.23/chromedriver] found in cache

# %%
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

results = soup.find_all('div', class_='image_and_description_container')

information = []

for result in results:
    try:
        title = result.find('div', class_='content_title').text
        paragraph = result.find('div', class_='article_teaser_body').text
        
        image_path = result.find('div', class_='list_image')
        print(image_path.img['src'])

    
        article_info = {}
        article_info['title'] = result.find('div', class_='content_title').text
        article_info['paragraph'] = result.find('div', class_='article_teaser_body').text
        information.append(article_info)
        #article_info['image'] = result.find('div', class_='list_image')
   # title = result.find('div', class_='content_title').text
   # title_p = result.find('div', class_='article_teaser_body').text
    
    except:
        print(information)
# Out:
# /system/news_items/list_view_images/8886_1-Canyon-de-Chelly-National-Monument-320x240.jpg
# /system/news_items/list_view_images/8885_PIA24492_unannotated_Yeehgo_mosaic-320x240.jpg
# /system/news_items/list_view_images/8882_PIA24487-320x240.jpg
# /system/news_items/list_view_images/8881_PIA24485_K4_ZCAM_main_sol004_Delta_Remnant_unannotated-320x240.jpg
# /system/news_items/list_view_images/8880_pia23496-320.jpg
# /system/news_items/list_view_images/8878_PIA24421-320.jpg
# /system/news_items/list_view_images/8875_PIA24431-decoder-ring-320x240.jpg
# /system/news_items/list_view_images/8873_PIA2464-Perseverance_Sol3_Mastcam-Z_panorama-320x240.jpg
# /system/news_items/list_view_images/8872_Perseverance_SYN_chip_on_Mars_320x180optimized_30ps.gif
# /system/news_items/list_view_images/8870_PIA24422-Navcam-08_N_LRGB_0002_RAS_0010052_CYL_S_UNCORCLJ01-stretched-v2.jpg
# /system/news_items/list_view_images/8868_1-PIA24428-320.jpg
# /system/news_items/list_view_images/8867_PIA23720-320.jpg
# ...

# %%
for result in results:
    image_path = result.find('div', class_='list_image')
    print(image_path.img['src'])
# Out:
# /system/news_items/list_view_images/8886_1-Canyon-de-Chelly-National-Monument-320x240.jpg
# /system/news_items/list_view_images/8885_PIA24492_unannotated_Yeehgo_mosaic-320x240.jpg
# /system/news_items/list_view_images/8882_PIA24487-320x240.jpg
# /system/news_items/list_view_images/8881_PIA24485_K4_ZCAM_main_sol004_Delta_Remnant_unannotated-320x240.jpg
# /system/news_items/list_view_images/8880_pia23496-320.jpg
# /system/news_items/list_view_images/8878_PIA24421-320.jpg
# /system/news_items/list_view_images/8875_PIA24431-decoder-ring-320x240.jpg
# /system/news_items/list_view_images/8873_PIA2464-Perseverance_Sol3_Mastcam-Z_panorama-320x240.jpg
# /system/news_items/list_view_images/8872_Perseverance_SYN_chip_on_Mars_320x180optimized_30ps.gif
# /system/news_items/list_view_images/8870_PIA24422-Navcam-08_N_LRGB_0002_RAS_0010052_CYL_S_UNCORCLJ01-stretched-v2.jpg
# /system/news_items/list_view_images/8868_1-PIA24428-320.jpg
# /system/news_items/list_view_images/8867_PIA23720-320.jpg
# ...
